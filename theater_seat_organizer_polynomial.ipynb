# %%
import gurobipy as gp
from gurobipy import GRB

# %% [markdown]
# # The Model

# %%
theater_seat_organizer = gp.Model()

# %% [markdown]
# # The Parameters

# %%
# Uncomment the single file that will be tested and recomment the previous case

test_case = "testcase1-poly.txt"
#test_case = "testcase2-poly.txt"
#test_case = "testcase3-poly.txt"
#test_case = "testcase4-poly.txt"

f = open(test_case,"r")
testfile = f.readlines()

test_name = testfile[0].split("=")[1]

string_num_of_customers_in_group = testfile[1].split(" = ")[1]

#Convert list of string to list of int
number_of_customers_in_group_list = string_num_of_customers_in_group.strip("[").strip("\n").strip("]").split(",")
map_list = map(int, number_of_customers_in_group_list)
number_of_customers_in_group = list(map_list)

number_of_seats = int(testfile[2].split(" = ")[1])

group_bonus = int(testfile[3].split(" = ")[1])

# %% [markdown]
# # Decision Variables

# %%
person_inGroup_atSeat = {}

for group_num in range(len(number_of_customers_in_group)):
    for customer_index in range(0, number_of_customers_in_group[group_num]):
        for seat in range(number_of_seats):
            
            person_inGroup_atSeat[customer_index, group_num, seat] = theater_seat_organizer.addVar(vtype = GRB.BINARY, name = "person" + str(customer_index) + "_inGroup" + str(group_num) + "_atSeat" + str(seat))

# %% [markdown]
# # The Model

# %%
objectiveFunction = gp.LinExpr()

for group_num in range(len(number_of_customers_in_group)):
    for customer_index in range(0, number_of_customers_in_group[group_num]):
        for seat in range(number_of_seats):
            objectiveFunction += person_inGroup_atSeat[customer_index, group_num, seat]   
    
for group_num in range(len(number_of_customers_in_group)):
    
    objectiveFunction += 

theater_seat_organizer.setObjective(objectiveFunction,  GRB.MAXIMIZE)

# %% [markdown]
# # Constraints

# %%
# at most one person per seat
for seat in range(number_of_seats):
    at_most_one_person_per_seat = gp.LinExpr()
    
    for group_num in range(len(number_of_customers_in_group)):
        for customer_index in range(0, number_of_customers_in_group[group_num]):
            at_most_one_person_per_seat += person_inGroup_atSeat[customer_index, group_num, seat]   
    theater_seat_organizer.addConstr(at_most_one_person_per_seat <= 1, name = "at_most_one_person_at_seat" + str(seat))

# %%
# each person should be assigned to only one seat 
for group_num in range(len(number_of_customers_in_group)):
    for customer_index in range(0, number_of_customers_in_group[group_num]):
        seats_per_person = gp.LinExpr()
        
        for seat in range(number_of_seats):
            seats_per_person += person_inGroup_atSeat[customer_index, group_num, seat] 
            
        theater_seat_organizer.addConstr(seats_per_person <= 1, name = "person" + str(customer_index) + "_group" + str(group_num) + "_uniqueSeat")

# %%
# There must be an empty seat between groups 
for seat in range(number_of_seats - 1):
    
    for group_num in range(len(number_of_customers_in_group)):
        for other_group_num in range(len(number_of_customers_in_group)):
            
            if not(group_num == other_group_num):    
                
                for customer_index in range(0, number_of_customers_in_group[group_num]):
                    for customer2_index in range(0, number_of_customers_in_group[other_group_num]):
                        
                        seat1 = person_inGroup_atSeat[customer_index, group_num, seat]
                        seat2 = person_inGroup_atSeat[customer2_index, other_group_num, seat+1]
                        label = "person" + str(customer_index) + "_inGroup" + str(group_num) + "_andPerson" + str(customer2_index) + "+inGroup" + str(other_group_num) + "_cannotSitTogether"
                        theater_seat_organizer.addConstr( seat1 + seat2 <= 1, name = label)

# %% [markdown]
# # Optimize

# %%
theater_seat_organizer.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 2674786 rows, 25302 columns and 5423211 nonzeros
# Model fingerprint: 0x7f5f2e4a
# Variable types: 0 continuous, 25302 integer (25302 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e-02, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# MIP start from previous solve produced solution with objective 108.96 (100.11s)
# MIP start from previous solve produced solution with objective 113.97 (114.65s)
# MIP start from previous solve produced solution with objective 117.97 (474.14s)
# MIP start from previous solve produced solution with objective 121.98 (541.30s)
# MIP start from previous solve produced solution with objective 123.99 (740.01s)
# MIP start from previous solve produced solution with objective 126.99 (2112.44s)
# MIP start from previous solve produced solution with objective 127.98 (2247.75s)
# MIP start from previous solve produced solution with objective 128.99 (2289.89s)
# Loaded MIP start from previous solve with objective 128.99
# Processed MIP start in 2578.66 seconds
#
# Presolve removed 1 rows and 367 columns (presolve time = 7s) ...
# Presolve removed 2552713 rows and 367 columns (presolve time = 10s) ...
# Presolve removed 2579950 rows and 367 columns (presolve time = 15s) ...
# Presolve removed 2587833 rows and 367 columns (presolve time = 20s) ...
# Presolve removed 2595465 rows and 367 columns (presolve time = 25s) ...
# Presolve removed 2600414 rows and 367 columns (presolve time = 30s) ...
# Presolve removed 2606575 rows and 367 columns (presolve time = 35s) ...
# Presolve removed 2613432 rows and 367 columns (presolve time = 40s) ...
# Presolve removed 2620222 rows and 367 columns (presolve time = 45s) ...
# Presolve removed 2620222 rows and 367 columns (presolve time = 50s) ...
# Presolve removed 2620222 rows and 367 columns (presolve time = 57s) ...
# Presolve removed 2620222 rows and 367 columns (presolve time = 62s) ...
# Presolve removed 2623376 rows and 4321 columns (presolve time = 65s) ...
# Presolve removed 2623376 rows and 4321 columns
# Presolve time: 65.33s
# Presolved: 51410 rows, 20981 columns, 1989603 nonzeros
# Variable types: 0 continuous, 20981 integer (20981 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.1000000e-01   0.000000e+00   2.099360e+04   2650s
#      921    1.0997340e+02   0.000000e+00   1.053084e+04   2650s
#     4041    1.2947369e+02   0.000000e+00   1.340284e+05   2655s
#     4681    1.3100000e+02   0.000000e+00   0.000000e+00   2657s
# Concurrent spin time: 2.85s
#
# Solved with primal simplex
#
# Root relaxation: objective 1.310000e+02, 4681 iterations, 15.29 seconds
# Total elapsed time = 2671.94s
# Total elapsed time = 2677.62s
# Total elapsed time = 2683.43s
# Total elapsed time = 2686.90s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  131.00000    0  264  128.99000  131.00000  1.56%     - 2689s
#      0     0  131.00000    0  603  128.99000  131.00000  1.56%     - 2713s
#      0     0  131.00000    0  146  128.99000  131.00000  1.56%     - 2920s
#      0     0  131.00000    0  179  128.99000  131.00000  1.56%     - 2938s
#      0     0  131.00000    0  145  128.99000  131.00000  1.56%     - 2956s
#      0     0  131.00000    0  144  128.99000  131.00000  1.56%     - 2958s
#      0     0  131.00000    0   88  128.99000  131.00000  1.56%     - 2974s
#      0     0  131.00000    0   83  128.99000  131.00000  1.56%     - 2976s
#      0     0  131.00000    0   54  128.99000  131.00000  1.56%     - 3003s
#      0     0  131.00000    0   58  128.99000  131.00000  1.56%     - 3005s
#      0     0  131.00000    0   41  128.99000  131.00000  1.56%     - 3020s
#      0     0  131.00000    0  118  128.99000  131.00000  1.56%     - 3024s
#      0     0  131.00000    0   45  128.99000  131.00000  1.56%     - 3041s
#      0     0  131.00000    0   93  128.99000  131.00000  1.56%     - 3044s
#      0     0  131.00000    0   50  128.99000  131.00000  1.56%     - 3059s
#      0     0  131.00000    0  348  128.99000  131.00000  1.56%     - 3065s
#      0     0  131.00000    0   52  128.99000  131.00000  1.56%     - 3078s
#      0     0  131.00000    0   52  128.99000  131.00000  1.56%     - 3091s
#      0     2  131.00000    0   52  128.99000  131.00000  1.56%     - 3158s
#      1     4  131.00000    1   90  128.99000  131.00000  1.56%  6719 3160s
#      5     8  131.00000    2  198  128.99000  131.00000  1.56%  1719 3318s
#      9    12  131.00000    3  163  128.99000  131.00000  1.56%  1116 3322s
#     15    18  131.00000    5  190  128.99000  131.00000  1.56%   801 3325s
#     17    24  131.00000    5  152  128.99000  131.00000  1.56%   730 3330s
#     23    32  131.00000    8  180  128.99000  131.00000  1.56%   652 3349s
# H   30    32                     129.9900000  131.00000  0.78%   828 3349s
#     31    65  131.00000   11  151  129.99000  131.00000  0.78%   823 3371s
#     64    91  131.00000   17  276  129.99000  131.00000  0.78%   596 3435s
#     90    99  131.00000   21   71  129.99000  131.00000  0.78%   808 3549s
#     98   217  131.00000   21  108  129.99000  131.00000  0.78%   974 3664s
#    216   351  131.00000   51  114  129.99000  131.00000  0.78%   817 3768s
#    350   515  131.00000   81  205  129.99000  131.00000  0.78%   742 3852s
#    522   575  131.00000  124  251  129.99000  131.00000  0.78%   717 4013s
# H  556   175                     131.0000000  131.00000  0.00%   698 4013s
#
# Cutting planes:
#   Clique: 198
#   Zero half: 2
#
# Explored 582 nodes (539927 simplex iterations) in 4014.28 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 131 129.99 128.99 ... 108.96
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.310000000000e+02, best bound 1.310000000000e+02, gap 0.0000%

# %% [markdown]
# # Post Process

# %%
seating_scheme = list()
for seat in range(number_of_seats):
    seatFound = False
    for group_num in range(len(number_of_customers_in_group)):
        for customer_index in range(0, number_of_customers_in_group[group_num]):
            result = person_inGroup_atSeat[customer_index, group_num, seat]
            
            if( result.x == 1 ):
                seatFound = True
                print( "Seat" + str(seat) + ": person" + str(customer_index) + " fromGroup" + str(group_num))
                
                seating_scheme.append((customer_index, group_num))
    
    if(not seatFound):
        print("Seat" + str(seat) + ": <empty>")
        seating_scheme.append(None)
# Out:
# Seat0: person5 fromGroup13
# Seat1: person0 fromGroup13
# Seat2: person3 fromGroup13
# Seat3: person4 fromGroup13
# Seat4: <empty>
# Seat5: person2 fromGroup17
# Seat6: person0 fromGroup17
# Seat7: person1 fromGroup17
# Seat8: person3 fromGroup17
# Seat9: <empty>
# Seat10: person1 fromGroup5
# Seat11: person3 fromGroup5
# Seat12: person4 fromGroup5
# Seat13: person5 fromGroup5
# Seat14: person2 fromGroup5
# Seat15: person0 fromGroup5
# Seat16: <empty>
# Seat17: person0 fromGroup15
# Seat18: person6 fromGroup15
# Seat19: person2 fromGroup15
# Seat20: person5 fromGroup15
# Seat21: <empty>
# Seat22: person7 fromGroup14
# Seat23: person0 fromGroup14
# Seat24: person1 fromGroup14
# Seat25: <empty>
# Seat26: person7 fromGroup20
# Seat27: person6 fromGroup20
# Seat28: person8 fromGroup20
# Seat29: person3 fromGroup20
# Seat30: person4 fromGroup20
# Seat31: person1 fromGroup20
# Seat32: person0 fromGroup20
# Seat33: <empty>
# Seat34: person1 fromGroup13
# Seat35: <empty>
# Seat36: person2 fromGroup12
# Seat37: person5 fromGroup12
# Seat38: person3 fromGroup12
# Seat39: person6 fromGroup12
# Seat40: person0 fromGroup12
# Seat41: person4 fromGroup12
# Seat42: person1 fromGroup12
# Seat43: <empty>
# Seat44: person3 fromGroup7
# Seat45: person1 fromGroup7
# Seat46: person0 fromGroup7
# Seat47: person4 fromGroup7
# Seat48: person2 fromGroup7
# Seat49: person7 fromGroup7
# Seat50: person6 fromGroup7
# Seat51: person5 fromGroup7
# Seat52: <empty>
# Seat53: person2 fromGroup13
# Seat54: person7 fromGroup13
# Seat55: person6 fromGroup13
# Seat56: <empty>
# Seat57: person6 fromGroup6
# Seat58: person4 fromGroup6
# Seat59: person2 fromGroup6
# Seat60: person0 fromGroup6
# Seat61: person1 fromGroup6
# Seat62: person3 fromGroup6
# Seat63: person5 fromGroup6
# Seat64: <empty>
# Seat65: person2 fromGroup10
# Seat66: <empty>
# Seat67: person2 fromGroup20
# Seat68: person5 fromGroup20
# Seat69: <empty>
# Seat70: person1 fromGroup4
# Seat71: person3 fromGroup4
# Seat72: person0 fromGroup4
# Seat73: person2 fromGroup4
# Seat74: <empty>
# Seat75: person5 fromGroup18
# Seat76: person0 fromGroup18
# Seat77: person1 fromGroup18
# Seat78: person3 fromGroup18
# Seat79: <empty>
# Seat80: person4 fromGroup18
# Seat81: person6 fromGroup18
# Seat82: person2 fromGroup18
# Seat83: <empty>
# Seat84: person6 fromGroup14
# Seat85: person8 fromGroup14
# Seat86: person5 fromGroup14
# Seat87: person2 fromGroup14
# Seat88: person4 fromGroup14
# Seat89: person3 fromGroup14
# Seat90: <empty>
# Seat91: person0 fromGroup8
# Seat92: person1 fromGroup8
# Seat93: <empty>
# Seat94: person1 fromGroup16
# Seat95: person4 fromGroup16
# Seat96: person2 fromGroup16
# Seat97: person0 fromGroup16
# Seat98: <empty>
# Seat99: person2 fromGroup11
# Seat100: person0 fromGroup11
# Seat101: <empty>
# Seat102: person0 fromGroup0
# Seat103: person1 fromGroup0
# Seat104: person2 fromGroup0
# Seat105: person4 fromGroup0
# Seat106: person3 fromGroup0
# Seat107: <empty>
# Seat108: person1 fromGroup15
# Seat109: person4 fromGroup15
# Seat110: person3 fromGroup15
# Seat111: person7 fromGroup15
# Seat112: person8 fromGroup15
# Seat113: <empty>
# Seat114: person4 fromGroup10
# Seat115: person3 fromGroup10
# Seat116: person1 fromGroup10
# Seat117: person0 fromGroup10
# Seat118: <empty>
# Seat119: person3 fromGroup16
# Seat120: <empty>
# Seat121: person4 fromGroup2
# Seat122: person6 fromGroup2
# Seat123: person5 fromGroup2
# Seat124: person2 fromGroup2
# Seat125: person0 fromGroup2
# Seat126: person1 fromGroup2
# Seat127: person7 fromGroup2
# Seat128: person3 fromGroup2
# Seat129: <empty>
# Seat130: person5 fromGroup9
# Seat131: person1 fromGroup9
# Seat132: person4 fromGroup9
# Seat133: person2 fromGroup9
# Seat134: person0 fromGroup9
# Seat135: person3 fromGroup9
# Seat136: <empty>
# Seat137: person0 fromGroup3
# Seat138: <empty>
# Seat139: person2 fromGroup19
# Seat140: person7 fromGroup19
# Seat141: person5 fromGroup19
# Seat142: person4 fromGroup19
# Seat143: person0 fromGroup19
# Seat144: person3 fromGroup19
# Seat145: person1 fromGroup19
# Seat146: person6 fromGroup19
# Seat147: <empty>
# Seat148: person5 fromGroup11
# Seat149: person4 fromGroup11
# Seat150: person3 fromGroup11
# Seat151: person1 fromGroup11
# Seat152: <empty>
# Seat153: person2 fromGroup1
# Seat154: person0 fromGroup1
# Seat155: person1 fromGroup1
# Seat156: person3 fromGroup1
# Seat157: person6 fromGroup1
# Seat158: person5 fromGroup1
# Seat159: person4 fromGroup1

# %%
genericSpacing = list()
last_group = -1
for value in seating_scheme:
    if(type(value) == tuple and value[1] != last_group):
        genericSpacing.append((None,None))
        genericSpacing.append(value)
        last_group = value[1]
        
    
    elif(type(value) == tuple and value[1] == last_group):
        genericSpacing.append(value)
        
genericSpacing.pop(0)

while(genericSpacing[0][1] == genericSpacing[-1][1]):
    genericSpacing.append(genericSpacing[0])
    genericSpacing.pop(0)
    
genericSpacing.pop(0)
    
for members in genericSpacing:
    if not (members[0] == None):
        print("person " + str(members[0] + 1) + " from group " + str(members[1] + 1))
    else:
        print("<SPACE>")
# Out:
# person 1 from group 14
# person 4 from group 14
# person 5 from group 14
# <SPACE>
# person 3 from group 18
# person 1 from group 18
# person 2 from group 18
# person 4 from group 18
# <SPACE>
# person 2 from group 6
# person 4 from group 6
# person 5 from group 6
# person 6 from group 6
# person 3 from group 6
# person 1 from group 6
# <SPACE>
# person 1 from group 16
# person 7 from group 16
# person 3 from group 16
# person 6 from group 16
# <SPACE>
# person 8 from group 15
# person 1 from group 15
# person 2 from group 15
# <SPACE>
# person 8 from group 21
# person 7 from group 21
# person 9 from group 21
# person 4 from group 21
# person 5 from group 21
# person 2 from group 21
# person 1 from group 21
# <SPACE>
# person 2 from group 14
# <SPACE>
# person 3 from group 13
# person 6 from group 13
# person 4 from group 13
# person 7 from group 13
# person 1 from group 13
# person 5 from group 13
# person 2 from group 13
# <SPACE>
# person 4 from group 8
# person 2 from group 8
# person 1 from group 8
# person 5 from group 8
# person 3 from group 8
# person 8 from group 8
# person 7 from group 8
# person 6 from group 8
# <SPACE>
# person 3 from group 14
# person 8 from group 14
# person 7 from group 14
# <SPACE>
# person 7 from group 7
# person 5 from group 7
# person 3 from group 7
# person 1 from group 7
# person 2 from group 7
# person 4 from group 7
# person 6 from group 7
# <SPACE>
# person 3 from group 11
# <SPACE>
# person 3 from group 21
# person 6 from group 21
# <SPACE>
# person 2 from group 5
# person 4 from group 5
# person 1 from group 5
# person 3 from group 5
# <SPACE>
# person 6 from group 19
# person 1 from group 19
# person 2 from group 19
# person 4 from group 19
# person 5 from group 19
# person 7 from group 19
# person 3 from group 19
# <SPACE>
# person 7 from group 15
# person 9 from group 15
# person 6 from group 15
# person 3 from group 15
# person 5 from group 15
# person 4 from group 15
# <SPACE>
# person 1 from group 9
# person 2 from group 9
# <SPACE>
# person 2 from group 17
# person 5 from group 17
# person 3 from group 17
# person 1 from group 17
# <SPACE>
# person 3 from group 12
# person 1 from group 12
# <SPACE>
# person 1 from group 1
# person 2 from group 1
# person 3 from group 1
# person 5 from group 1
# person 4 from group 1
# <SPACE>
# person 2 from group 16
# person 5 from group 16
# person 4 from group 16
# person 8 from group 16
# person 9 from group 16
# <SPACE>
# person 5 from group 11
# person 4 from group 11
# person 2 from group 11
# person 1 from group 11
# <SPACE>
# person 4 from group 17
# <SPACE>
# person 5 from group 3
# person 7 from group 3
# person 6 from group 3
# person 3 from group 3
# person 1 from group 3
# person 2 from group 3
# person 8 from group 3
# person 4 from group 3
# <SPACE>
# person 6 from group 10
# person 2 from group 10
# person 5 from group 10
# person 3 from group 10
# person 1 from group 10
# person 4 from group 10
# <SPACE>
# person 1 from group 4
# <SPACE>
# person 3 from group 20
# person 8 from group 20
# person 6 from group 20
# person 5 from group 20
# person 1 from group 20
# person 4 from group 20
# person 2 from group 20
# person 7 from group 20
# <SPACE>
# person 6 from group 12
# person 5 from group 12
# person 4 from group 12
# person 2 from group 12
# <SPACE>
# person 3 from group 2
# person 1 from group 2
# person 2 from group 2
# person 4 from group 2
# person 7 from group 2
# person 6 from group 2
# person 5 from group 2

# %%
for group_num in range(len(groupAccepted)):
    if(groupAccepted[group_num].x != 1):
        print("Group " + str(group_num + 1) + " is excluded")
    else:
        print("Group " + str(group_num + 1) + " is accepted")
#print(groupAccepted)
# Out:
# Group 1 is accepted
# Group 2 is accepted
# Group 3 is accepted
# Group 4 is accepted
# Group 5 is accepted
# Group 6 is accepted
# Group 7 is accepted
# Group 8 is accepted
# Group 9 is accepted
# Group 10 is accepted
# Group 11 is accepted
# Group 12 is accepted
# Group 13 is accepted
# Group 14 is accepted
# Group 15 is accepted
# Group 16 is accepted
# Group 17 is accepted
# Group 18 is accepted
# Group 19 is accepted
# Group 20 is accepted
# Group 21 is accepted
