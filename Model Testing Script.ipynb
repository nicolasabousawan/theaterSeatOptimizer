# %% [markdown]
# # Testing Script

# %%
import gurobipy as gp
from gurobipy import GRB
from math import exp

def optimizeTheater(seatSize, groupSize, cost):
    number_of_customers_in_group = groupSize
    number_of_seats = seatSize
    non_vax_cost = cost
    
    theater_seat_organizer = gp.Model()
    
    person_inGroup_atSeat = {}

    for group_num in range(len(number_of_customers_in_group)):
        for customer_index in range(0, number_of_customers_in_group[group_num]):
            for seat in range(number_of_seats):

                person_inGroup_atSeat[customer_index, group_num, seat] = theater_seat_organizer.addVar(vtype = GRB.BINARY, name = "person" + str(customer_index) + "_inGroup" + str(group_num) + "_atSeat" + str(seat))

    groupAccepted = {}
    for group_num in range(len(number_of_customers_in_group)):
        groupAccepted[group_num] = theater_seat_organizer.addVar(vtype = GRB.BINARY, name = "group" + str(group_num) + "_admitted")


    objectiveFunction = gp.LinExpr()

    for group_num in range(len(number_of_customers_in_group)):
        for customer_index in range(0, number_of_customers_in_group[group_num]):
            for seat in range(number_of_seats):
                objectiveFunction += person_inGroup_atSeat[customer_index, group_num, seat]   

    for group_num in range(len(number_of_customers_in_group)):
        objectiveFunction -= non_vax_cost * (1-groupAccepted[group_num])

    theater_seat_organizer.setObjective(objectiveFunction,  GRB.MAXIMIZE)
    
    # at most one person per seat
    for seat in range(number_of_seats):
        at_most_one_person_per_seat = gp.LinExpr()

        for group_num in range(len(number_of_customers_in_group)):
            for customer_index in range(0, number_of_customers_in_group[group_num]):
                at_most_one_person_per_seat += person_inGroup_atSeat[customer_index, group_num, seat]   
        theater_seat_organizer.addConstr(at_most_one_person_per_seat <= 1, name = "at_most_one_person_at_seat" + str(seat))

    # the whole group must be added
    for group_num in range(len(number_of_customers_in_group)):

        group_must_be_added = gp.LinExpr() # collects the sum of all the seats the group sits in
        is_group_accepted = gp.LinExpr(number_of_customers_in_group[group_num] * groupAccepted[group_num]) #determines if the group will be seated or not

        for customer_index in range(0, number_of_customers_in_group[group_num]):
            for seat in range(number_of_seats):
                group_must_be_added += person_inGroup_atSeat[customer_index, group_num, seat]   

        theater_seat_organizer.addConstr(group_must_be_added == is_group_accepted, name = "is_group_" + str(group_num) + "_accepted")

    # each person should be assigned to only one seat 
    for group_num in range(len(number_of_customers_in_group)):
        for customer_index in range(0, number_of_customers_in_group[group_num]):
            seats_per_person = gp.LinExpr()

            for seat in range(number_of_seats):
                seats_per_person += person_inGroup_atSeat[customer_index, group_num, seat] 

            theater_seat_organizer.addConstr(seats_per_person <= 1, name = "person" + str(customer_index) + "_group" + str(group_num) + "_uniqueSeat")
            
    # There must be an empty seat between groups 
    for seat in range(number_of_seats - 1):

        for group_num in range(len(number_of_customers_in_group)):
            for other_group_num in range(len(number_of_customers_in_group)):

                if not(group_num == other_group_num):    

                    for customer_index in range(0, number_of_customers_in_group[group_num]):
                        for customer2_index in range(0, number_of_customers_in_group[other_group_num]):

                            seat1 = person_inGroup_atSeat[customer_index, group_num, seat]
                            seat2 = person_inGroup_atSeat[customer2_index, other_group_num, seat+1]
                            label = "person" + str(customer_index) + "_inGroup" + str(group_num) + "_andPerson" + str(customer2_index) + "+inGroup" + str(other_group_num) + "_cannotSitTogether"
                            theater_seat_organizer.addConstr( seat1 + seat2 <= 1, name = label)
                            
    theater_seat_organizer.optimize()
    
    seating_scheme = list()
    for seat in range(number_of_seats):
        seatFound = False
        for group_num in range(len(number_of_customers_in_group)):
            for customer_index in range(0, number_of_customers_in_group[group_num]):
                result = person_inGroup_atSeat[customer_index, group_num, seat]

                if( result.x == 1 ):
                    seatFound = True
                    print( "Seat" + str(seat) + ": person" + str(customer_index) + " fromGroup" + str(group_num))

                    seating_scheme.append((customer_index, group_num))

        if(not seatFound):
            print("Seat" + str(seat) + ": <empty>")
            seating_scheme.append(None)
            
    genericSpacing = list()
    last_group = -1
    for value in seating_scheme:
        if(type(value) == tuple and value[1] != last_group):
            genericSpacing.append((None,None))
            genericSpacing.append(value)
            last_group = value[1]


        elif(type(value) == tuple and value[1] == last_group):
            genericSpacing.append(value)

    genericSpacing.pop(0)

    while(genericSpacing[0][1] == genericSpacing[-1][1]):
        genericSpacing.append(genericSpacing[0])
        genericSpacing.pop(0)

    genericSpacing.pop(0)

    for members in genericSpacing:
        if not (members[0] == None):
            print("person " + str(members[0] + 1) + " from group " + str(members[1] + 1))
        else:
            print("<SPACE>")
            
    for group_num in range(len(groupAccepted)):
        if(groupAccepted[group_num].x != 1):
            print("Group " + str(group_num + 1) + " is excluded")
        else:
            print("Group " + str(group_num + 1) + " is accepted")

# %%
# Test Variables
number_of_customers_in_group = [[5,7,8,1,4,6,7,8,2,6,5,6,7,8,9,9,5,4,7,8,9]]
number_of_seats = [160]
non_vax_cost = [10]

# %%
for index, inputs in enumerate(number_of_customers_in_group):
    print("TEST CASE #" + str(index))
    
    optimizeTheater(number_of_seats[index], inputs, non_vax_cost[index])
# Out:
# TEST CASE #0
# Academic license - for non-commercial use only - expires 2022-01-04
# Using license file C:\Users\olyny\gurobi.lic
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (win64)
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# Optimize a model with 2583426 rows, 20981 columns and 5229129 nonzeros
# Model fingerprint: 0xdb60606c
# Variable types: 0 continuous, 20981 integer (20981 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+00]
#   Objective range  [1e+00, 1e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -210.0000000
# Presolve removed 1 rows and 0 columns (presolve time = 5s) ...
# Presolve removed 2493090 rows and 0 columns (presolve time = 10s) ...
# Presolve removed 2504393 rows and 0 columns (presolve time = 15s) ...
# Presolve removed 2516773 rows and 0 columns (presolve time = 20s) ...
# Presolve removed 2532128 rows and 0 columns (presolve time = 25s) ...
# Presolve removed 2532128 rows and 0 columns (presolve time = 30s) ...
# Presolve removed 2532128 rows and 0 columns
# Presolve time: 32.53s
# Presolved: 51298 rows, 20981 columns, 1990272 nonzeros
# Variable types: 0 continuous, 20981 integer (20981 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -2.1000000e+02   0.000000e+00   5.456000e+04     36s
#     5358    1.2660419e+02   0.000000e+00   8.798508e+06     40s
# Concurrent spin time: 0.11s
#
# Solved with dual simplex
#
# Root relaxation: objective 1.310000e+02, 3569 iterations, 7.11 seconds
# Total elapsed time = 53.01s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  131.00000    0  542 -210.00000  131.00000   162%     -   86s
# H    0     0                      69.0000000  131.00000  89.9%     -   86s
# H    0     0                      80.0000000  131.00000  63.7%     -   87s
#      0     0  131.00000    0 1084   80.00000  131.00000  63.7%     -  115s
#      0     0  131.00000    0  377   80.00000  131.00000  63.7%     -  233s
#      0     0  131.00000    0  293   80.00000  131.00000  63.7%     -  264s
# H    0     0                      86.0000000  131.00000  52.3%     -  265s
#      0     0  131.00000    0  306   86.00000  131.00000  52.3%     -  267s
#      0     0  131.00000    0  199   86.00000  131.00000  52.3%     -  293s
# H    0     0                     100.0000000  131.00000  31.0%     -  296s
#      0     0  131.00000    0  288  100.00000  131.00000  31.0%     -  301s
#      0     0  131.00000    0  145  100.00000  131.00000  31.0%     -  323s
#      0     0  131.00000    0  136  100.00000  131.00000  31.0%     -  325s
#      0     0  131.00000    0  263  100.00000  131.00000  31.0%     -  341s
# H    0     0                     102.0000114  131.00000  28.4%     -  346s
#      0     0  131.00000    0  745  102.00001  131.00000  28.4%     -  350s
#      0     0  131.00000    0   87  102.00001  131.00000  28.4%     -  379s
#      0     0  131.00000    0  101  102.00001  131.00000  28.4%     -  384s
#      0     0  131.00000    0   92  102.00001  131.00000  28.4%     -  392s
#      0     0  131.00000    0   78  102.00001  131.00000  28.4%     -  408s
#      0     0  131.00000    0   81  102.00001  131.00000  28.4%     -  414s
# H    0     0                     113.0000000  131.00000  15.9%     -  415s
#      0     0  131.00000    0  213  113.00000  131.00000  15.9%     -  419s
#      0     0  131.00000    0   96  113.00000  131.00000  15.9%     -  440s
#      0     0  131.00000    0   89  113.00000  131.00000  15.9%     -  445s
# H    0     2                     115.0000000  131.00000  13.9%     -  482s
#      0     2  131.00000    0   81  115.00000  131.00000  13.9%     -  482s
#      5     8  131.00000    2  169  115.00000  131.00000  13.9%   965  485s
#     15    20  131.00000    5  120  115.00000  131.00000  13.9%   575  490s
#     19    26  131.00000    6  119  115.00000  131.00000  13.9%   546  495s
#     25    31  131.00000    8  388  115.00000  131.00000  13.9%   612  563s
#     30    37  131.00000    9  323  115.00000  131.00000  13.9%   585  588s
#     36    75  131.00000   11  137  115.00000  131.00000  13.9%  1620  619s
# H   73    75                     117.0000000  131.00000  12.0%  1227  619s
#     74   164  131.00000   21  186  117.00000  131.00000  12.0%  1224  712s
#    163   350  131.00000   50  193  117.00000  131.00000  12.0%   996  791s
#    365   390  131.00000    5  166  117.00000  131.00000  12.0%   838  861s
#    405   519  131.00000   11  173  117.00000  131.00000  12.0%   938  935s
#    534   691  131.00000   49   81  117.00000  131.00000  12.0%   929  999s
# H  537   283                     131.0000000  131.00000  0.00%   925  999s
#
# Cutting planes:
#   Clique: 279
#   Zero half: 14
#
# Explored 714 nodes (847795 simplex iterations) in 999.79 seconds
# Thread count was 4 (of 4 available processors)
#
# Solution count 10: 131 117 115 ... -210
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.310000000000e+02, best bound 1.310000000000e+02, gap 0.0000%
# Seat0: person0 fromGroup20
# Seat1: person1 fromGroup20
# Seat2: person3 fromGroup20
# Seat3: person5 fromGroup20
# Seat4: person4 fromGroup20
# Seat5: person6 fromGroup20
# Seat6: person8 fromGroup20
# Seat7: person7 fromGroup20
# Seat8: person2 fromGroup20
# Seat9: <empty>
# Seat10: person4 fromGroup6
# Seat11: person6 fromGroup6
# Seat12: <empty>
# Seat13: person3 fromGroup9
# Seat14: person5 fromGroup9
# Seat15: person2 fromGroup9
# Seat16: person4 fromGroup9
# Seat17: person0 fromGroup9
# Seat18: person1 fromGroup9
# Seat19: <empty>
# Seat20: person0 fromGroup1
# Seat21: person1 fromGroup1
# Seat22: person6 fromGroup1
# Seat23: person3 fromGroup1
# Seat24: <empty>
# Seat25: person2 fromGroup5
# Seat26: <empty>
# Seat27: person4 fromGroup16
# Seat28: person1 fromGroup16
# Seat29: person3 fromGroup16
# Seat30: person2 fromGroup16
# Seat31: person0 fromGroup16
# Seat32: <empty>
# Seat33: person4 fromGroup10
# Seat34: person3 fromGroup10
# Seat35: person1 fromGroup10
# Seat36: person2 fromGroup10
# Seat37: <empty>
# Seat38: person6 fromGroup7
# Seat39: person5 fromGroup7
# Seat40: person0 fromGroup7
# Seat41: person1 fromGroup7
# Seat42: person4 fromGroup7
# Seat43: <empty>
# Seat44: person5 fromGroup12
# Seat45: person2 fromGroup12
# Seat46: person1 fromGroup12
# Seat47: <empty>
# Seat48: person6 fromGroup12
# Seat49: person4 fromGroup12
# Seat50: person0 fromGroup12
# Seat51: person3 fromGroup12
# Seat52: <empty>
# Seat53: person5 fromGroup1
# Seat54: person4 fromGroup1
# Seat55: person2 fromGroup1
# Seat56: <empty>
# Seat57: person0 fromGroup11
# Seat58: person5 fromGroup11
# Seat59: <empty>
# Seat60: person1 fromGroup2
# Seat61: person0 fromGroup2
# Seat62: person5 fromGroup2
# Seat63: <empty>
# Seat64: person0 fromGroup18
# Seat65: person1 fromGroup18
# Seat66: person5 fromGroup18
# Seat67: person6 fromGroup18
# Seat68: <empty>
# Seat69: person1 fromGroup15
# Seat70: person5 fromGroup15
# Seat71: person4 fromGroup15
# Seat72: person8 fromGroup15
# Seat73: person2 fromGroup15
# Seat74: person0 fromGroup15
# Seat75: person6 fromGroup15
# Seat76: person3 fromGroup15
# Seat77: person7 fromGroup15
# Seat78: <empty>
# Seat79: person3 fromGroup18
# Seat80: person2 fromGroup18
# Seat81: person4 fromGroup18
# Seat82: <empty>
# Seat83: person4 fromGroup14
# Seat84: person3 fromGroup14
# Seat85: person7 fromGroup14
# Seat86: person1 fromGroup14
# Seat87: person2 fromGroup14
# Seat88: person6 fromGroup14
# Seat89: person5 fromGroup14
# Seat90: person0 fromGroup14
# Seat91: person8 fromGroup14
# Seat92: <empty>
# Seat93: person3 fromGroup6
# Seat94: person5 fromGroup6
# Seat95: person2 fromGroup6
# Seat96: person0 fromGroup6
# Seat97: person1 fromGroup6
# Seat98: <empty>
# Seat99: person0 fromGroup19
# Seat100: person4 fromGroup19
# Seat101: person7 fromGroup19
# Seat102: person2 fromGroup19
# Seat103: person1 fromGroup19
# Seat104: person3 fromGroup19
# Seat105: person5 fromGroup19
# Seat106: person6 fromGroup19
# Seat107: <empty>
# Seat108: person4 fromGroup11
# Seat109: person2 fromGroup11
# Seat110: person3 fromGroup11
# Seat111: person1 fromGroup11
# Seat112: <empty>
# Seat113: person2 fromGroup0
# Seat114: person4 fromGroup0
# Seat115: person1 fromGroup0
# Seat116: person0 fromGroup0
# Seat117: person3 fromGroup0
# Seat118: <empty>
# Seat119: person0 fromGroup17
# Seat120: person3 fromGroup17
# Seat121: person1 fromGroup17
# Seat122: person2 fromGroup17
# Seat123: <empty>
# Seat124: person0 fromGroup3
# Seat125: <empty>
# Seat126: person4 fromGroup5
# Seat127: person5 fromGroup5
# Seat128: person1 fromGroup5
# Seat129: person0 fromGroup5
# Seat130: person3 fromGroup5
# Seat131: <empty>
# Seat132: person7 fromGroup7
# Seat133: person3 fromGroup7
# Seat134: person2 fromGroup7
# Seat135: <empty>
# Seat136: person0 fromGroup8
# Seat137: person1 fromGroup8
# Seat138: <empty>
# Seat139: person0 fromGroup10
# Seat140: <empty>
# Seat141: person3 fromGroup13
# Seat142: person2 fromGroup13
# Seat143: person0 fromGroup13
# Seat144: person7 fromGroup13
# Seat145: person5 fromGroup13
# Seat146: person6 fromGroup13
# Seat147: person1 fromGroup13
# Seat148: person4 fromGroup13
# Seat149: <empty>
# Seat150: person3 fromGroup4
# Seat151: person1 fromGroup4
# Seat152: person0 fromGroup4
# Seat153: person2 fromGroup4
# Seat154: <empty>
# Seat155: person6 fromGroup2
# Seat156: person3 fromGroup2
# Seat157: person2 fromGroup2
# Seat158: person4 fromGroup2
# Seat159: person7 fromGroup2
# person 2 from group 21
# person 4 from group 21
# person 6 from group 21
# person 5 from group 21
# person 7 from group 21
# person 9 from group 21
# person 8 from group 21
# person 3 from group 21
# <SPACE>
# person 5 from group 7
# person 7 from group 7
# <SPACE>
# person 4 from group 10
# person 6 from group 10
# person 3 from group 10
# person 5 from group 10
# person 1 from group 10
# person 2 from group 10
# <SPACE>
# person 1 from group 2
# person 2 from group 2
# person 7 from group 2
# person 4 from group 2
# <SPACE>
# person 3 from group 6
# <SPACE>
# person 5 from group 17
# person 2 from group 17
# person 4 from group 17
# person 3 from group 17
# person 1 from group 17
# <SPACE>
# person 5 from group 11
# person 4 from group 11
# person 2 from group 11
# person 3 from group 11
# <SPACE>
# person 7 from group 8
# person 6 from group 8
# person 1 from group 8
# person 2 from group 8
# person 5 from group 8
# <SPACE>
# person 6 from group 13
# person 3 from group 13
# person 2 from group 13
# person 7 from group 13
# person 5 from group 13
# person 1 from group 13
# person 4 from group 13
# <SPACE>
# person 6 from group 2
# person 5 from group 2
# person 3 from group 2
# <SPACE>
# person 1 from group 12
# person 6 from group 12
# <SPACE>
# person 2 from group 3
# person 1 from group 3
# person 6 from group 3
# <SPACE>
# person 1 from group 19
# person 2 from group 19
# person 6 from group 19
# person 7 from group 19
# <SPACE>
# person 2 from group 16
# person 6 from group 16
# person 5 from group 16
# person 9 from group 16
# person 3 from group 16
# person 1 from group 16
# person 7 from group 16
# person 4 from group 16
# person 8 from group 16
# <SPACE>
# person 4 from group 19
# person 3 from group 19
# person 5 from group 19
# <SPACE>
# person 5 from group 15
# person 4 from group 15
# person 8 from group 15
# person 2 from group 15
# person 3 from group 15
# person 7 from group 15
# person 6 from group 15
# person 1 from group 15
# person 9 from group 15
# <SPACE>
# person 4 from group 7
# person 6 from group 7
# person 3 from group 7
# person 1 from group 7
# person 2 from group 7
# <SPACE>
# person 1 from group 20
# person 5 from group 20
# person 8 from group 20
# person 3 from group 20
# person 2 from group 20
# person 4 from group 20
# person 6 from group 20
# person 7 from group 20
# <SPACE>
# person 5 from group 12
# person 3 from group 12
# person 4 from group 12
# person 2 from group 12
# <SPACE>
# person 3 from group 1
# person 5 from group 1
# person 2 from group 1
# person 1 from group 1
# person 4 from group 1
# <SPACE>
# person 1 from group 18
# person 4 from group 18
# person 2 from group 18
# person 3 from group 18
# <SPACE>
# person 1 from group 4
# <SPACE>
# person 5 from group 6
# person 6 from group 6
# person 2 from group 6
# person 1 from group 6
# person 4 from group 6
# <SPACE>
# person 8 from group 8
# person 4 from group 8
# person 3 from group 8
# <SPACE>
# person 1 from group 9
# person 2 from group 9
# <SPACE>
# person 1 from group 11
# <SPACE>
# person 4 from group 14
# person 3 from group 14
# person 1 from group 14
# person 8 from group 14
# person 6 from group 14
# person 7 from group 14
# person 2 from group 14
# person 5 from group 14
# <SPACE>
# person 4 from group 5
# person 2 from group 5
# person 1 from group 5
# person 3 from group 5
# <SPACE>
# person 7 from group 3
# person 4 from group 3
# person 3 from group 3
# person 5 from group 3
# person 8 from group 3
# Group 1 is accepted
# Group 2 is accepted
# Group 3 is accepted
# Group 4 is accepted
# Group 5 is accepted
# Group 6 is accepted
# Group 7 is accepted
# Group 8 is accepted
# Group 9 is accepted
# Group 10 is accepted
# Group 11 is accepted
# Group 12 is accepted
# Group 13 is accepted
# Group 14 is accepted
# Group 15 is accepted
# Group 16 is accepted
# Group 17 is accepted
# Group 18 is accepted
# Group 19 is accepted
# Group 20 is accepted
# Group 21 is accepted
